# %%
import pickle

# %%
# load list from pickel
with open('./all_cars', 'rb') as f:
    df_list = pickle.load(f)

# %%
df_list
# Out:
# [('Volkswagen\neGolf 300',
#   'https://www.spritmonitor.de/en/detail/1322155.html'),
#  ('Smart\nEQ', 'https://www.spritmonitor.de/en/detail/1467321.html'),
#  ('Nissan\ne-NV200', 'https://www.spritmonitor.de/en/detail/811710.html'),
#  ('Polestar\nPolestar 2 SM LR FWD',
#   'https://www.spritmonitor.de/en/detail/1355617.html'),
#  ('BMW\ni3 94Ah', 'https://www.spritmonitor.de/en/detail/1008662.html'),
#  ('Hyundai\nelectric', 'https://www.spritmonitor.de/en/detail/1171093.html'),
#  ('Fiat\nFIAT 500e', 'https://www.spritmonitor.de/en/detail/1034667.html'),
#  ('Kia\nEdition24', 'https://www.spritmonitor.de/en/detail/1446086.html'),
#  ('Hyundai\nKona Electric 136ch Intuitive Euro6d-T EVAP',
#   'https://www.spritmonitor.de/en/detail/1371743.html'),
#  ('Renault\nZOE Intens', 'https://www.spritmonitor.de/en/detail/760806.html'),
#  ('Tesla Motors\nSR+', 'https://www.spritmonitor.de/en/detail/1309070.html'),
#  ('Renault\n50', 'https://www.spritmonitor.de/en/detail/1142333.html'),
# ...
